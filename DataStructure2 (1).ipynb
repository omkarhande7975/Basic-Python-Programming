# %%
marklist = [1, 2, 3, 4, 5,]

# %%
tuple(marklist)
# Out:
# (1, 2, 3, 4, 5)

# %%
single = (10,)

# %%
single
# Out:
# (10,)

# %%
type(single)
# Out:
# tuple

# %%
single = (10)

# %%
single
# Out:
# 10

# %%
type(single)
# Out:
# int

# %%
#tuple unpacking

# %%
nums = (1,2,3,4,5,6,7,8,9)

# %%
# unpacking values

# %%
a, b, c, d, e, f, g, h, i = nums

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
d
# Out:
# 4

# %%
e
# Out:
# 5

# %%
f
# Out:
# 6

# %%
g
# Out:
# 7

# %%
h
# Out:
# 8

# %%
i
# Out:
# 9

# %%
nums = (1,"java",3.2,True)

# %%
a,b,c,d = nums

# %%
a
# Out:
# 1

# %%
b
# Out:
# 'java'

# %%
c
# Out:
# 3.2

# %%
d
# Out:
# True

# %%
omkar = ("Welcome to python programming")

# %%
omkar.upper()
# Out:
# 'WELCOME TO PYTHON PROGRAMMING'

# %%
omkar.lower()
# Out:
# 'welcome to python programming'

# %%
omkar.title()
# Out:
# 'Welcome To Python Programming'

# %%
omkar.capitalize()
# Out:
# 'Welcome to python programming'

# %%
len(omkar)
# Out:
# 29

# %%
print("Welcome\nto\npython\nprogramming")
# Out:
# Welcome
# to
# python
# programming

# %%
s = {1,2,3,4,}
print(s)
# Out:
# {1, 2, 3, 4}

# %%
type(s)
# Out:
# set

# %%
set = {1,2,3,4,5,}
print(set)
# Out:
# {1, 2, 3, 4, 5}

# %%
set.add(6)
print(set)
# Out:
# {1, 2, 4, 5, 6, 8}

# %%
set.update([7,8])
print(set)
# Out:
# {1, 2, 4, 5, 6, 7, 8}

# %%
set.remove(7)
print(set)
# Out:
# {1, 2, 4, 5, 6, 8}

# %%
set.pop()
print(set)
# Out:
# {2, 4, 5, 6, 8}

# %%
set.discard(6)
print(set)
# Out:
# {2, 4, 5, 8}

# %%
set.clear()
print(set)
# Out:
# set()

# %%
sets = {2,"java",3.3,True}
print(s)
# Out:
# {'java', 2, 3.3, True}

# %%
len(sets)
# Out:
# 4

# %%
99 in set
# Out:
# False

# %%
for set in set:
    set
    print(set)
# Out:
# java
# 2
# 3.3
# True

# %%
s = {1,14.3,"string",True}
print(s)
# Out:
# {1, 'string', 14.3}

# %%
set = {2,13.3,"string",True}
print(set)
# Out:
# {True, 2, 13.3, 'string'}

# %%
a = {1,2}
b = {3,6}

# %%
a.union(b)
# Out:
# {1, 2, 3, 6}

# %%
a = {1,2,3}
b = {2,3,4}

# %%
a - b
# Out:
# {1}

# %%
a.difference(b)
# Out:
# {1}

# %%
a.symmetric_difference(b)
# Out:
# {1, 4}

# %%
nums = {10,20,30,40,50}
print(nums)
# Out:
# {50, 20, 40, 10, 30}

# %%
max(nums)
# Out:
# 50

# %%
sum(nums)
# Out:
# 150

# %%
min(nums)
# Out:
# 10

# %%
list = (10,20,30)
print(list)
# Out:
# (10, 20, 30)
