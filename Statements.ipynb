# %%
# if statements

# %%
number = 10

# %%
if number > 0:
    print("positive Number")
# Out:
# positive Number

# %%
number = 5

# %%
if number > 10:
    print("positive Number")

# %%
# if...else Statement

# %%
age = 16

# %%
if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Minor

# %%
number = 16

# %%
if number >= 5:
    print("odd")
else:
    print("even")
# Out:
# odd

# %%
# Even or odd program

# %%
num = 7

# %%
if num % 2 == 0:
    print(" Even Number")
else:    
    print(" Odd Number")
# Out:
#  Odd Number

# %%
marks = 82

# %%
if marks >= 90:
    print("Grade A")

elif marks >= 75:
    print("Grade B")

elif marks >= 50:
    print("Grade C")

else:
    print("Fail")
# Out:
# Grade B

# %%
# Multiple Condition using AND

# %%
age = 25
salary = 40000

# %%
if age >= 18 and salary >= 30000:
    print("Eligible for Loan")
else:
    print("Not Eligible")
# Out:
# Eligible for Loan
