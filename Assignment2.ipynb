# %%
# 1. Write a Python program to create a user-defined function, call the function, and display the returned value.

# %%
def square(num):
    return num * num

result = square(5)

print("Returned value:", result)
# Out:
# Returned value: 25

# %%
# 2. Write a Python program to find the factorial of a number using a function, display the result, and validate the input.

# %%
def factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact *= i
    return fact
try:
    num = int(input("Enter a non-negative integer: "))

    if num < 0:
        print("Error: Factorial is not defined for negative numbers.")
    else:
        result = factorial(num)
        print("Factorial of", num, "is", result)

except ValueError:
    print("Error: Please enter a valid integer.")
# Out:
# Enter a non-negative integer:  4
# Factorial of 4 is 24

# %%
# 3. Write a Python program to check whether a number is prime using a function, count its factors, and display the result.

# %%
def check_prime(n):
    factor_count = 0

    for i in range(1, n + 1):
        if n % i == 0:
            factor_count += 1

    if factor_count == 2:
        return factor_count, True
    else:
        return factor_count, False

num = int(input("Enter a number: "))

factors, is_prime = check_prime(num)

print("Number of factors:", factors)

if is_prime:
    print(num, "is a Prime Number.")
else:
    print(num, "is Not a Prime Number.")
# Out:
# Enter a number:  11
# Number of factors: 2
# 11 is a Prime Number.

# %%
# 4. Write a Python program to find the largest of three numbers using a function, calculate their average, and display the smallest number.

# %%
def find_largest(a, b, c):
    if a >= b and a >= c:
        return a
    elif b >= a and b >= c:
        return b
    else:
        return c


num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))


largest = max(num1, num2, num3)

average = (num1 + num2 + num3) / 3


smallest = min(num1, num2, num3)


print("Largest number:", largest)
print("Average:", average)
print("Smallest number:", smallest)
# Out:
# Enter first number:  25
# Enter second number:  34
# Enter third number:  89
# Largest number: 89.0
# Average: 49.333333333333336
# Smallest number: 25.0

# %%
# 5. Write a Python program to demonstrate default arguments, keyword arguments, and positional arguments.

# %%
def student_info(name, age=18, city="Pune"):
    print("Name :", name)
    print("Age  :", age)
    print("City :", city)
    print()

print("Using Positional Arguments:")
student_info("omkar", 19, "Mumbai")

print("Using Keyword Arguments:")
student_info(name="rushikesh", city="Delhi", age=20)

print("Using Default Arguments:")
student_info("shrawan")
# Out:
# Using Positional Arguments:
# Name : omkar
# Age  : 19
# City : Mumbai
#
# Using Keyword Arguments:
# Name : rushikesh
# Age  : 20
# City : Delhi
#
# Using Default Arguments:
# Name : shrawan
# Age  : 18
# City : Pune

# %%
# 6. Write a Python program to demonstrate the use of *args, calculate the sum, and find the maximum value.

# %%
def calculate(*args):
    total = sum(args)
    maximum = max(args)

    print("Numbers:", args)
    print("Sum =", total)
    print("Maximum Value =", maximum)


calculate(10, 20, 30, 40, 50)
# Out:
# Numbers: (10, 20, 30, 40, 50)
# Sum = 150
# Maximum Value = 50

# %%
# 7. Write a Python program to demonstrate the use of **kwargs, display all key-value pairs, and count the arguments passed.

# %%
def display_details(**kwargs):
    print("Key-Value Pairs:")

    for key, value in kwargs.items():
        print(key, ":", value)

    print("\nTotal Arguments Passed =", len(kwargs))


display_details(name="omkar", age=19, city="Pune", course="Python")
# Out:
# Key-Value Pairs:
# name : omkar
# age : 19
# city : Pune
# course : Python
#
# Total Arguments Passed = 4

# %%
# 8. Write a Python program to calculate the factorial using recursion, count recursive calls, and display the result.

# %%
call_count = 0


def factorial(n):
    global call_count
    call_count += 1

    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)


num = int(input("Enter a non-negative integer: "))

if num < 0:
    print("Factorial is not defined for negative numbers.")
else:
    result = factorial(num)

    print("Factorial of", num, "is", result)
    print("Number of recursive calls =", call_count)
# Out:
# Enter a non-negative integer:  4
# Factorial of 4 is 24
# Number of recursive calls = 4

# %%
# 9. Write a Python program to calculate the sum of digits using recursion, reverse the number, and count its digits.

# %%
def sum_digits(n):
    if n == 0:
        return 0
    return (n % 10) + sum_digits(n // 10)


def reverse_number(n, rev=0):
    if n == 0:
        return rev
    return reverse_number(n // 10, rev * 10 + n % 10)

def count_digits(n):
    if n == 0:
        return 0
    return 1 + count_digits(n // 10)


num = int(input("Enter a number: "))

digit_count = 1 if num == 0 else count_digits(abs(num))


print("Sum of digits =", sum_digits(abs(num)))
print("Reversed number =", reverse_number(abs(num)))
print("Number of digits =", digit_count)
# Out:
# Enter a number:  45
# Sum of digits = 9
# Reversed number = 54
# Number of digits = 2

# %%
# 10. Write a Python program using a lambda function to find the square, cube, and double of a number.

# %%
square = lambda x: x ** 2
cube = lambda x: x ** 3
double = lambda x: x * 2


num = int(input("Enter a number: "))


print("Square =", square(num))
print("Cube =", cube(num))
print("Double =", double(num))
# Out:
# Enter a number:  8
# Square = 64
# Cube = 512
# Double = 16

# %%
# 11. Write a Python program using map() to calculate squares, cubes, and square roots of list elements.

# %%
import math
numbers = [2,6,4,8,3,5]


squares = list(map(lambda x: x ** 2, numbers))
cubes = list(map(lambda x: x ** 3, numbers))
square_roots = list(map(lambda x: math.sqrt(x), numbers))

print("Numbers       :", numbers)
print("Squares       :", squares)
print("Cubes         :", cubes)
print("Square Roots  :", square_roots)
# Out:
# Numbers       : [2, 6, 4, 8, 3, 5]
# Squares       : [4, 36, 16, 64, 9, 25]
# Cubes         : [8, 216, 64, 512, 27, 125]
# Square Roots  : [1.4142135623730951, 2.449489742783178, 2.0, 2.8284271247461903, 1.7320508075688772, 2.23606797749979]

# %%
# 12. Write a Python program using filter() to extract even numbers, odd numbers, and numbers greater than a specified value.

# %%
numbers = [2,4,6,8,3,5,67,99,45,68]

limit = 20

even_numbers = list(filter(lambda x: x % 2 == 0, numbers))


odd_numbers = list(filter(lambda x: x % 2 != 0, numbers))


greater_numbers = list(filter(lambda x: x > limit, numbers))

print("Numbers            :", numbers)
print("Even Numbers       :", even_numbers)
print("Odd Numbers        :", odd_numbers)
print("Numbers > 20       :", greater_numbers)
# Out:
# Numbers            : [2, 4, 6, 8, 3, 5, 67, 99, 45, 68]
# Even Numbers       : [2, 4, 6, 8, 68]
# Odd Numbers        : [3, 5, 67, 99, 45]
# Numbers > 20       : [67, 99, 45, 68]

# %%
# 13. Write a Python program using reduce() to calculate the sum, product, and maximum value of list elements.

# %%
from functools import reduce


numbers = [2, 3, 5, 7, 10]


total_sum = reduce(lambda x, y: x + y, numbers)


product = reduce(lambda x, y: x * y, numbers)


maximum = reduce(lambda x, y: x if x > y else y, numbers)

print("Numbers :", numbers)
print("Sum     :", total_sum)
print("Product :", product)
print("Maximum :", maximum)
# Out:
# Numbers : [2, 3, 5, 7, 10]
# Sum     : 27
# Product : 2100
# Maximum : 10

# %%
# 14. Write a Python program to create a text file, write data into it, and close the file properly.

# %%
file = open("sample.txt", "w")


file.write("Hello, this is a sample text file.\n")
file.write("We are writing data using Python.\n")
file.write("File handling is easy in Python.\n")

file.close()

print("Data written to file successfully.")
# Out:
# Data written to file successfully.

# %%
# 15. Write a Python program to read a text file, count the number of lines, and display the contents.

# %%
file = open("sample.txt", "r")

# Read all contents of the file
content = file.read()

# Close the file
file.close()

# Count number of lines
lines = content.splitlines()
line_count = len(lines)

# Display file contents
print("File Contents:\n")
print(content)

# Display number of lines
print("\nNumber of lines:", line_count)
# Out:
# File Contents:
#
# Hello, this is a sample text file.
# We are writing data using Python.
# File handling is easy in Python.
#
#
# Number of lines: 3

# %%
# 16. Write a Python program to append data to a file, display the updated contents, and count the total words.

# %%
with open("sample.txt", "r") as file:
    content = file.read()


words = content.split()
word_count = len(words)


print("Updated File Contents:\n")
print(content)


print("\nTotal number of words:", word_count)
# Out:
# Updated File Contents:
#
# Hello, this is a sample text file.
# We are writing data using Python.
# File handling is easy in Python.
#
#
# Total number of words: 19

# %%
# 17. Write a Python program to copy the contents of one file to another, compare both files, and display the file sizes.

# %%
import os
source_file = "sample.txt"
dest_file = "copy_sample.txt"


with open(source_file, "r") as src:
    content = src.read()

with open(dest_file, "w") as dest:
    dest.write(content)


with open(source_file, "r") as f1, open(dest_file, "r") as f2:
    same_content = f1.read() == f2.read()

size_source = os.path.getsize(source_file)
size_dest = os.path.getsize(dest_file)


print("File copied successfully.\n")

print("Files have same content:", same_content)

print("Size of source file:", size_source, "bytes")
print("Size of destination file:", size_dest, "bytes")
# Out:
# File copied successfully.
#
# Files have same content: True
# Size of source file: 105 bytes
# Size of destination file: 105 bytes

# %%
# 18. Write a Python program to search for a word in a file, count its occurrences, and replace it with another word.

# %%
filename = "sample.txt"


search_word = "Python"
replace_word = "Java"

with open(filename, "r") as file:
    content = file.read()


count = content.count(search_word)

updated_content = content.replace(search_word, replace_word)


with open(filename, "w") as file:
    file.write(updated_content)


print("Word searched      :", search_word)
print("Occurrences found  :", count)
print("Replacement word   :", replace_word)

print("\nUpdated file content:\n")
print(updated_content)
# Out:
# Word searched      : Python
# Occurrences found  : 2
# Replacement word   : Java
#
# Updated file content:
#
# Hello, this is a sample text file.
# We are writing data using Java.
# File handling is easy in Java.

# %%
# 19. Write a Python program to create multiple files, list all created files, and delete a selected file.

# %%
import os

files = ["file1.txt", "file2.txt", "file3.txt"]


for fname in files:
    with open(fname, "w") as f:
        f.write(f"This is {fname}\n")

print("Files created successfully.\n")

print("Created files:")
for fname in files:
    if os.path.exists(fname):
        print("-", fname)


print("\nAll .txt files in directory:")
for f in os.listdir():
    if f.endswith(".txt"):
        print("-", f)

delete_file = input("\nEnter the file name to delete: ")


if os.path.exists(delete_file):
    os.remove(delete_file)
    print(delete_file, "deleted successfully.")
else:
    print("File not found.")
# Out:
# Files created successfully.
#
# Created files:
# - file1.txt
# - file2.txt
# - file3.txt
#
# All .txt files in directory:
# - copy_sample.txt
# - file1.txt
# - file2.txt
# - file3.txt
# - python.txt
# - sample.txt
# Enter the file name to delete:  copy_sample.txt
# copy_sample.txt deleted successfully.

# %%
# 20. Write a Python program to handle division-by-zero exceptions, display a custom error message, and continue execution.

# %%
def divide_numbers(a, b):
    try:
        result = a / b
        print(f"Result: {a} / {b} = {result}")
    except ZeroDivisionError:
        print("Error: Division by zero is not allowed.")

numbers = [(10, 2), (5, 0), (8, 4), (9, 3)]


for num in numbers:
    divide_numbers(num[0], num[1])

print("\nProgram execution completed successfully.")
# Out:
# Result: 10 / 2 = 5.0
# Error: Division by zero is not allowed.
# Result: 8 / 4 = 2.0
# Result: 9 / 3 = 3.0
#
# Program execution completed successfully.

# %%
# 21. Write a Python program to handle multiple exceptions, display the exception type, and log the error message.

# %%
import logging


logging.basicConfig(
    filename="error_log.txt",
    level=logging.ERROR,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def process_data(a, b):
    try:
        result = a / b
        print("Result:", result)

    except ZeroDivisionError as e:
        print("Error Type:", type(e).__name__)
        print("Message:", e)
        logging.error(f"ZeroDivisionError: {e}")

    except TypeError as e:
        print("Error Type:", type(e).__name__)
        print("Message:", e)
        logging.error(f"TypeError: {e}")

    except Exception as e:
        print("Error Type:", type(e).__name__)
        print("Message:", e)
        logging.error(f"Unexpected Error: {e}")

test_cases = [
    (10, 2),
    (5, 0),
    (10, "a"),
]

for a, b in test_cases:
    process_data(a, b)

print("\nProgram completed. Check 'error_log.txt' for logged errors.")
# Out:
# Result: 5.0
# Error Type: ZeroDivisionError
# Message: division by zero
# Error Type: TypeError
# Message: unsupported operand type(s) for /: 'int' and 'str'
#
# Program completed. Check 'error_log.txt' for logged errors.

# %%
# 22. Write a Python program to demonstrate try, except, and finally, and display execution flow messages.

# %%
def divide(a, b):
    print("Inside function: Starting division process")

    try:
        print("Try block: Attempting division")
        result = a / b
        print("Result =", result)

    except ZeroDivisionError:
        print("Except block: Cannot divide by zero!")

    finally:
        print("Finally block: Execution completed (always runs)")

    print("Function ended\n")



print("Case 1:")
divide(10, 2)

print("Case 2:")
divide(5, 0)

print("Program execution finished.")
# Out:
# Case 1:
# Inside function: Starting division process
# Try block: Attempting division
# Result = 5.0
# Finally block: Execution completed (always runs)
# Function ended
#
# Case 2:
# Inside function: Starting division process
# Try block: Attempting division
# Except block: Cannot divide by zero!
# Finally block: Execution completed (always runs)
# Function ended
#
# Program execution finished.

# %%
# 23. Write a Python program to raise a custom exception, handle the exception, and display a user-friendly message.

# %%
class InvalidAgeError(Exception):
    pass

def check_age(age):
    try:
        if age < 18:
            raise InvalidAgeError("Age must be 18 or above to proceed.")
        else:
            print("Access granted. You are eligible.")

    except InvalidAgeError as e:
        print("Custom Exception Caught!")
        print("Message:", e)


check_age(20)
print()
check_age(15)
# Out:
# Access granted. You are eligible.
#
# Custom Exception Caught!
# Message: Age must be 18 or above to proceed.

# %%
# 24. Write a Python program to handle a file-not-found exception, create the missing file, and write default content into it.

# %%
filename = "data.txt"

try:

    with open(filename, "r") as file:
        content = file.read()
        print("File Contents:\n", content)

except FileNotFoundError:
    print("File not found. Creating a new file with default content...")


    with open(filename, "w") as file:
        file.write("Default File Created\n")
        file.write("This is sample default content.\n")
        file.write("File was missing and now created automatically.\n")

    print("File created successfully with default content.")

finally:
    print("Program execution completed.")
# Out:
# File not found. Creating a new file with default content...
# File created successfully with default content.
# Program execution completed.

# %%
# 25. Write a Python program to create a custom exception class, validate user input, and handle invalid data.

# %%
filename = "data.txt"

try:

    with open(filename, "r") as file:
        content = file.read()
        print("File Contents:\n", content)

except FileNotFoundError:
    print("File not found. Creating a new file with default content...")


    with open(filename, "w") as file:
        file.write("Default File Created\n")
        file.write("This is sample default content.\n")
        file.write("File was missing and now created automatically.\n")

    print("File created successfully with default content.")

finally:
    print("Program execution completed.")
# Out:
# File Contents:
#  Default File Created
# This is sample default content.
# File was missing and now created automatically.
#
# Program execution completed.
