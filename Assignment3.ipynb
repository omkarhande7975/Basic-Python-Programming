# %%
# 1. Write a Python program to accept a number, check whether it is positive, negative, or zero, and display an appropriate message

# %%
num = float(input("Enter a number: "))


if num > 0:
    print("The number is positive.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# Enter a number:  6
# The number is positive.

# %%
# 2. Write a Python program to accept a number, check whether it is even or odd, and display its square.

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("The number is even.")
else: 
    print("The number is odd.")


square = num * num
print("square of the number is:", square)
# Out:
# Enter a number:  8
# The number is even.
# square of the number is: 64

# %%
# 3. Write a Python program to accept two numbers, find the larger number, and check whether both numbers are equal.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter secound number: "))

# Check if both numbers are equal
if num1 == num2:
    print("Both numbers are equal.")
else:
    # Find the larger number
    if num1 > num2:
        print("First number is larger:", num1)
    else:
        print("Second number is larger:", num2)
# Out:
# Enter first number:  23
# Enter secound number:  56
# Second number is larger: 56.0

# %%
# 4. Write a Python program to accept three numbers, find the largest number, smallest number, and their average.

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))


largest = max(num1, num2, num3)
smallest = min(num1, num2, num3)


average = (num1 + num2 + num3) / 3


print("Largest number is:", largest)
print("Smallest number is:", smallest)
print("Average is:", average)
# Out:
# Enter first number:  34
# Enter second number:  25
# Enter third number:  43
# Largest number is: 43.0
# Smallest number is: 25.0
# Average is: 34.0

# %%
# 5. Write a Python program to accept marks of five subjects, calculate total marks, percentage, and grade using if-elif-else.

# %%
s1 = float(input("Enter marks of subject1: "))
s2 = float(input("Enter marks of subject 2: "))
s3 = float(input("Enter marks of subject 3: "))
s4 = float(input("Enter marks of subject 4: "))
s5 = float(input("Enter marks of subject 5: "))


total = s1 + s2 + s3 + s4 + s5
percentage = (total / 500) * 100


print("Total Marks:", total)
print("Percentage:", percentage)


if percentage >= 90:
    grade = "A+"
elif percentage >= 80:
    grade = "A"
elif percentage >= 70:
    grade = "B"
elif percentage >= 60:
    grade = "C"
elif percentage >= 50:
    grade = "D"
else:
    grade = "F (Fail)"

print("Grade:", grade)
# Out:
# Enter marks of subject1:  50
# Enter marks of subject 2:  89
# Enter marks of subject 3:  96
# Enter marks of subject 4:  92
# Enter marks of subject 5:  80
# Total Marks: 407.0
# Percentage: 81.39999999999999
# Grade: A

# %%
# 6. Write a Python program to check whether a student has passed or failed based on marks in each subject, total marks, and percentage.

# %%
s1 = float(input("Enter marks of subject 1: "))
s2 = float(input("Enter marks of subject 2: "))
s3 = float(input("Enter marks of subject 3: "))
s4 = float(input("Enter marks of subject 4: "))
s5 = float(input("Enter marks of subject 5: "))


total = s1 + s2 + s3 + s4 + s5
percentage = (total / 500) * 100


print("Total Marks:", total)
print("Percentage:", percentage)



if s1 >= 40 and s2 >= 40 and s3 >= 40 and s4 >= 40 and s5 >= 40 and percentage >= 40:
    print("Result: PASS")
else:
    print("Result: FAIL")
# Out:
# Enter marks of subject 1:  50
# Enter marks of subject 2:  98
# Enter marks of subject 3:  90
# Enter marks of subject 4:  89
# Enter marks of subject 5:  59
# Total Marks: 386.0
# Percentage: 77.2
# Result: PASS

# %%
# 7. Write a Python program to check whether a year is a leap year, century year, or ordinary year.

# %%
year = int(input("Enter a year: "))


if year % 100 == 0:
    print("It is a century year.")


    if year % 400 == 0:
        print("It is also a leap year.")
    else:
        print("It is not a leap year.")

else:

    if year % 4 == 0:
        print("It is a leap year.")
    else:
        print("It is an ordinary year.")
# Out:
# Enter a year:  2024
# It is a leap year.

# %%
# 8. Write a Python program to check whether a character is a vowel, consonant, digit, or special symbol.

# %%
ch = input("Enter a single character: ")


if len(ch) != 1:
    print("Please enter only one character.")
else:

    if ch.lower() in 'aeiou':
        print("It is a vowel.")


    elif ch.isalpha():
        print("It is a consonant.")


    elif ch.isdigit():
        print("It is a digit.")

    else:
        print("It is a special symbol.")
# Out:
# Enter a single character:  A
# It is a vowel.

# %%
# 9. Write a Python program to check whether a character is uppercase, lowercase, digit, or special character.

# %%
ch = input("Enter a single character: ")


if len(ch) != 1:
    print("Please enter only one character.")
else:

    if ch.isupper():
        print("It is an uppercase letter.")


    elif ch.islower():
        print("It is a lowercase letter.")


    elif ch.isdigit():
        print("It is a digit.")


    else:
        print("It is a special character.")
# Out:
# Enter a single character:  D
# It is an uppercase letter.

# %%
# 10. Write a Python program to check whether a number is divisible by 5, 11, both 5 and 11, or neither.

# %%
num = int(input("Enter a number: "))


if num % 5 == 0 and num % 11 == 0:
    print("The number is divisible by both 5 and 11.")
elif num % 5 == 0:
    print("The number is divisible by 5.")
elif num % 11 == 0:
    print("The number is divisible by 11.")
else:
    print("The number is not divisible by 5 or 11.")
# Out:
# Enter a number:  15
# The number is divisible by 5.

# %%
# 11. Write a Python program to check whether a number is divisible by 2, 3, and 6 using logical operators.

# %%
num = int(input("Enter a number: "))


if num % 2 == 0 and num % 3 == 0 and num % 6 == 0:
    print("The number is divisible by 2, 3, and 6.")
else:
    print("The number is not divisible by 2, 3, and 6.")
# Out:
# Enter a number:  12
# The number is divisible by 2, 3, and 6.

# %%
# 12. Write a Python program to accept the age of a person, check voting eligibility, senior citizen status, and driving eligibility

# %%
age = int(input("Enter your age: "))


if age >= 18:
    print("Eligible to vote.")
else:
    print("Not eligible to vote.")

if age >= 18:
    print("Eligible to drive.")
else:
    print("Not eligible to drive.")


if age >= 60:
    print("You are a senior citizen.")
else:
    print("You are not a senior citizen.")
# Out:
# Enter your age:  12
# Not eligible to vote.
# Not eligible to drive.
# You are not a senior citizen.

# %%
# 13. Write a Python program to calculate electricity bill charges based on unit slab rates and display the final bill amount.

# %%
units = float(input("Enter number of units consumed: "))

bill = 0


if units <= 100:
    bill = units * 1.5
elif units <= 200:
    bill = (100 * 1.5) + (units - 100) * 2.5
elif units <= 300:
    bill = (100 * 1.5) + (100 * 2.5) + (units - 200) * 4
else:
    bill = (100 * 1.5) + (100 * 2.5) + (100 * 4) + (units - 300) * 6


print("Total Electricity Bill: Rs.", bill)
# Out:
# Enter number of units consumed:  4
# Total Electricity Bill: Rs. 6.0

# %%
# 14. Write a Python program to calculate income tax based on income slabs and display the tax amount.

# %%
income = float(input("Enter your annual income: "))

tax = 0


if income <= 250000:
    tax = 0
elif income <= 500000:
    tax = (income - 250000) * 0.05
elif income <= 1000000:
    tax = (250000 * 0.05) + (income - 500000) * 0.20
else:
    tax = (250000 * 0.05) + (500000 * 0.20) + (income - 1000000) * 0.30


print("Total Income Tax: Rs.", tax)
# Out:
# Enter your annual income:  150000
# Total Income Tax: Rs. 0

# %%
# 15. Write a Python program to create a menu-driven calculator using if-elif-else for addition, subtraction, multiplication, and division.

# %%
print("----- Calculator Menu -----")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")


choice = int(input("Enter your choice (1-4): "))


num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))


if choice == 1:
    print("Result:", num1 + num2)

elif choice == 2:
    print("Result:", num1 - num2)

elif choice == 3:
    print("Result:", num1 * num2)

elif choice == 4:
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Error: Division by zero is not allowed.")

else:
    print("Invalid choice! Please select between 1 and 4.")
# Out:
# ----- Calculator Menu -----
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter your choice (1-4):  3
# Enter first number:  43
# Enter second number:  3
# Result: 129.0

# %%
# 16. Write a Python program to create a menu-driven program to find area of circle, rectangle, triangle, and square.

# %%
print("1. Circle")
print("2. Rectangle")
print("3. Triangle")
print("4. Square")


choice = int(input("Enter your choice (1-4): "))


if choice == 1:
    r = float(input("Enter radius of circle: "))
    area = 3.14 * r * r
    print("Area of Circle:", area)

elif choice == 2:
    l = float(input("Enter length of rectangle: "))
    b = float(input("Enter breadth of rectangle: "))
    area = l * b
    print("Area of Rectangle:", area)

elif choice == 3:
    b = float(input("Enter base of triangle: "))
    h = float(input("Enter height of triangle: "))
    area = 0.5 * b * h
    print("Area of Triangle:", area)

elif choice == 4:
    s = float(input("Enter side of square: "))
    area = s * s
    print("Area of Square:", area)

else:
    print("Invalid choice! Please select between 1 and 4.")
# Out:
# 1. Circle
# 2. Rectangle
# 3. Triangle
# 4. Square
# Enter your choice (1-4):  4
# Enter side of square:  6
# Area of Square: 36.0

# %%
# 17. Write a Python program to check whether three sides form a valid triangle, identify its type, and calculate its perimeter.

# %%
# Out:
# Enter first side:  23
# Enter second side:  34
# Enter third side:  21
# It is a valid triangle.
# Perimeter of triangle: 78.0

# %%
a = float(input("Enter first side: "))
b = float(input("Enter second side: "))
c = float(input("Enter third side: "))

# Check validity using triangle inequality rule
if (a + b > c) and (a + c > b) and (b + c > a):
    print("It is a valid triangle.")

    # Find perimeter
    perimeter = a + b + c
    print("Perimeter of triangle:", perimeter)

    # Identify type of triangle
    if a == b == c:
        print("It is an Equilateral triangle.")
    elif a == b or b == c or a == c:
        print("It is an Isosceles triangle.")
    else:
        print("It is a Scalene triangle.")

else:
    print("The given sides do not form a valid triangle.")
# Out:
# Enter first side:  23
# Enter second side:  34
# Enter third side:  21
# It is a valid triangle.
# Perimeter of triangle: 78.0
# It is a Scalene triangle.

# %%
# 18. Write a Python program to check whether three angles form a valid triangle and identify whether it is acute, right, or obtuse.

# %%
a = float(input("Enter first angle: "))
b = float(input("Enter second angle: "))
c = float(input("Enter third angle: "))

# Check validity of triangle
if (a + b + c == 180) and a > 0 and b > 0 and c > 0:
    print("It is a valid triangle.")

    # Identify type of triangle
    if a < 90 and b < 90 and c < 90:
        print("It is an Acute triangle.")
    elif a == 90 or b == 90 or c == 90:
        print("It is a Right triangle.")
    else:
        print("It is an Obtuse triangle.")

else:
    print("The angles do not form a valid triangle.")
# Out:
# Enter first angle:  30
# Enter second angle:  45
# Enter third angle:  75
# The angles do not form a valid triangle.

# %%
# 19. Write a Python program to accept month number, display the month name, and show the number of days in that month.

# %%
month = int(input("Enter month number (1-12): "))


if month == 1:
    print("January - 31 days")
elif month == 2:
    print("February - 28 or 29 days")
elif month == 3:
    print("March - 31 days")
elif month == 4:
    print("April - 30 days")
elif month == 5:
    print("May - 31 days")
elif month == 6:
    print("June - 30 days")
elif month == 7:
    print("July - 31 days")
elif month == 8:
    print("August - 31 days")
elif month == 9:
    print("September - 30 days")
elif month == 10:
    print("October - 31 days")
elif month == 11:
    print("November - 30 days")
elif month == 12:
    print("December - 31 days")
else:
    print("Invalid month number! Please enter between 1 and 12.")
# Out:
# Enter month number (1-12):  8
# August - 31 days

# %%
# 20. Write a Python program to accept a weekday number, display the weekday name, and identify whether it is a weekday or weekend.

# %%
day = int(input("Enter weekday number (1-7): "))


if day == 1:
    print("Monday - Weekday")
elif day == 2:
    print("Tuesday - Weekday")
elif day == 3:
    print("Wednesday - Weekday")
elif day == 4:
    print("Thursday - Weekday")
elif day == 5:
    print("Friday - Weekday")
elif day == 6:
    print("Saturday - Weekend")
elif day == 7:
    print("Sunday - Weekend")
else:
    print("Invalid input! Please enter a number between 1 and 7.")
# Out:
# Enter weekday number (1-7):  5
# Friday - Weekday

# %%
# 21. Write a Python program to accept temperature, classify it as cold, normal, hot, or very hot, and convert it between Celsius and Fahrenheit.

# %%
print("----- Temperature Converter -----")
print("1. Celsius to Fahrenheit")
print("2. Fahrenheit to Celsius")

choice = int(input("Enter your choice (1 or 2): "))
temp = float(input("Enter temperature: "))

if choice == 1:

    converted = (temp * 9/5) + 32
    print("Temperature in Fahrenheit:", converted)


    if temp < 15:
        print("It is Cold.")
    elif temp < 25:
        print("It is Normal.")
    elif temp < 35:
        print("It is Hot.")
    else:
        print("It is Very Hot.")

elif choice == 2:

    converted = (temp - 32) * 5/9
    print("Temperature in Celsius:", converted)


    c = converted
    if c < 15:
        print("It is Cold.")
    elif c < 25:
        print("It is Normal.")
    elif c < 35:
        print("It is Hot.")
    else:
        print("It is Very Hot.")

else:
    print("Invalid choice!")
# Out:
# ----- Temperature Converter -----
# 1. Celsius to Fahrenheit
# 2. Fahrenheit to Celsius
# Enter your choice (1 or 2):  2
# Enter temperature:  17
# Temperature in Celsius: -8.333333333333334
# It is Cold.

# %%
# 22. Write a Python program to accept a password, check its length, validate whether it contains letters and digits, and display password strength.

# %%
password = input("Enter your password: ")


has_letter = False
has_digit = False


for ch in password:
    if ch.isalpha():
        has_letter = True
    elif ch.isdigit():
        has_digit = True

length = len(password)


if length < 6:
    print("Weak password (too short).")

elif has_letter and has_digit and length >= 8:
    print("Strong password.")

elif has_letter and has_digit:
    print("Moderate password.")

else:
    print("Weak password (must contain both letters and digits).")
# Out:
# Enter your password:  omii@123
# Strong password.

# %%
# 23. Write a Python program to accept a product price, apply discount based on price range, and calculate the final price.

# %%
price = float(input("Enter product price: "))

discount = 0


if price <= 1000:
    discount = 0
elif price <= 5000:
    discount = price * 0.05
elif price <= 10000:
    discount = price * 0.10
else:
    discount = price * 0.15


final_price = price - discount


print("Original Price:", price)
print("Discount:", discount)
print("Final Price:", final_price)
# Out:
# Enter product price:  70000
# Original Price: 70000.0
# Discount: 10500.0
# Final Price: 59500.0

# %%
# 24. Write a Python program to accept employee salary, calculate bonus based on salary range, and display total salary.

# %%
salary = float(input("Enter employee salary: "))

bonus = 0


if salary <= 10000:
    bonus = salary * 0.10
elif salary <= 20000:
    bonus = salary * 0.15
elif salary <= 50000:
    bonus = salary * 0.20
else:
    bonus = salary * 0.25


total_salary = salary + bonus

print("Basic Salary:", salary)
print("Bonus:", bonus)
print("Total Salary:", total_salary)
# Out:
# Enter employee salary:  500000
# Basic Salary: 500000.0
# Bonus: 125000.0
# Total Salary: 625000.0

# %%
# 25. Write a Python program to accept a number and use a conditional expression to find whether it is even or odd, positive or negative, and greater than 100.

# %%
num = int(input("Enter a number: "))

# Even or odd using conditional expression
even_odd = "Even" if num % 2 == 0 else "Odd"

# Positive, negative or zero
sign = "Positive" if num > 0 else ("Negative" if num < 0 else "Zero")

# Greater than 100 or not
greater = "Greater than 100" if num > 100 else "Not greater than 100"

# Display results
print(even_odd)
print(sign)
print(greater)
# Out:
# Enter a number:  67
# Odd
# Positive
# Not greater than 100
