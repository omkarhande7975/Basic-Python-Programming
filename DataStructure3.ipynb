# %%
numbers = {10,20,30,40}
print(numbers)
# Out:
# {40, 10, 20, 30}

# %%
set(numbers)
# Out:
# {10, 20, 30, 40}

# %%
# intersection

# %%
a = {1,2,3}
b = {2,3,4}

# %%
# Common element

# %%
a.intersection(b)
# Out:
# {2, 3}

# %%
# Using &

# %%
a & b
# Out:
# {2, 3}

# %%
# copying  set

# %%
b = a.copy()

# %%
b
# Out:
# {1, 2, 3}

# %%
# nested sets Using frozenset()

# %%
# Normal sets cannot contain sets
# Use frozenset for nested sets

# %%
a = frozenset({1, 2})

# %%
b = {a, 3}

# %%
b
# Out:
# {3, frozenset({1, 2})}

# %%
# frozen set

# %%
# immutable set

# %%
frozen = frozenset([1, 2, 3,])

# %%
type(frozen)
# Out:
# frozenset

# %%
#create dictionary

# %%
student = {
    "name": "omkar",
    "age": 19
}    
print(student)
# Out:
# {'name': 'omkar', 'age': 19}

# %%
character = {
    "name": "bmw",
    "model": 2026
    
}   
print(character)
# Out:
# {'name': 'bmw', 'model': 2026}

# %%
flowers = {
    "name": "rose",
    "color": "red"
}    
print(flowers)
# Out:
# {'name': 'rose', 'color': 'red'}

# %%
# mixed data type dictionary

# %%
mixed = {
    1: "one",
    "name": "python",
    True: 100
}    
print(mixed)
# Out:
# {1: 100, 'name': 'python'}

# %%
mixed = {
    3: "Three",
    "name": "java",
    True: 200
}    
print(mixed)
# Out:
# {3: 'Three', 'name': 'java', True: 200}

# %%
# Access using get()

# %%
student ["name"]
# Out:
# 'omkar'

# %%
# Access using get()

# %%
student.get("age")
# Out:
# 19

# %%
# Adding element

# %%
student["age"] = 19

# %%
student
# Out:
# {'name': 'omkar', 'age': 19}

# %%
student["marks"] = 100

# %%
student
# Out:
# {'name': 'omkar', 'age': 19, 'marks': 100}

# %%
# Modify value

# %%
student["age"] = 20
print(student)
# Out:
# {'name': 'omkar', 'age': 20, 'marks': 100}

# %%
# remove element

# %%
student.popitem()
# Out:
# ('marks', 100)

# %%
student
# Out:
# {}

# %%
# Remove all elements

# %%
student.clear()

# %%
student
# Out:
# {}

# %%
#Length of dictionary

# %%
student = {
    "name": "omkar",
    "age": 19
}    
print(student)
# Out:
# {'name': 'omkar', 'age': 19}

# %%
# Finding length

# %%
len(student)
# Out:
# 2

# %%
# checking key

# %%
"age" in student
# Out:
# True

# %%
"name" in student
# Out:
# True

# %%
# Loop throuth keys

# %%
student = {
    "name": "omkar",
    "age": 19
}

# %%
for student in student:
    student
    print(student)
# Out:
# name
# age

# %%
# Loop through values

# %%
for value in student.values():
    value
    print(value)
# Out:
# omkar
# 19

# %%
for item in student.items():
    item
    print(item)
# Out:
# ('name', 'omkar')
# ('age', 19)

# %%
#get all keys

# %%
student.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
# get all values

# %%
student.values()
# Out:
# dict_values(['omkar', 19])

# %%
#get all items

# %%
student.items()
# Out:
# dict_items([('name', 'omkar'), ('age', 19)])

# %%
#  copy dictionary

# %%
new_student = student.copy()

# %%
new_student
# Out:
# {'name': 'omkar', 'age': 19}

# %%
# nested dictionaries

# %%
student = {
    "student1": {
        "name": "omkar",
        "age": 21
    },
    "student2": {
        "name": "aman",
        "age": 22
    }
}

# %%
# Access  nested valuse

# %%
student["student1"]["name"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 student["student1"]["name"]
#
# NameError: name 'student' is not defined

# %%
#create a doctionary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 Student_name = omkar
#
# NameError: name 'omkar' is not defined
