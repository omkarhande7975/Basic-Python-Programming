# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Pandas

# %%
# Install Pandas

# %%
import pandas as pd

# %%
s = pd.Series([10,20,30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s = pd.Series([10,20,30], index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
student = {
    "name":"Omkar",
    "age":19,
    "marks":70
}

# %%
s = pd.Series(student)

# %%
s
# Out:
# name     Omkar
# age         19
# marks       70
# dtype: object

# %%
print(student)
# Out:
# {'name': 'Omkar', 'age': 19, 'marks': 70}

# %%
s = pd.Series(5, index = [0,1,2,3,4])

# %%
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %%
# Attributes

# %%
s = pd.Series([10,20,30], index = ['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.shape
# Out:
# (3,)

# %%
s*2
# Out:
# a    20
# b    40
# c    60
# dtype: int64

# %%
s = pd.Series([10,None,20])

# %%
s
# Out:
# 0    10.0
# 1     NaN
# 2    20.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s.dropna()
# Out:
# 0    10.0
# 2    20.0
# dtype: float64

# %%
s.fillna(5)
# Out:
# 0    10.0
# 1     5.0
# 2    20.0
# dtype: float64

# %%
s = pd.Series([1,2,2,3,3,3])

# %%
s
# Out:
# 0    1
# 1    2
# 2    2
# 3    3
# 4    3
# 5    3
# dtype: int64

# %%
s.value_counts()
# Out:
# 3    3
# 2    2
# 1    1
# Name: count, dtype: int64

# %%
s = pd.Series([10,20,30,40], index=['a','b','c','d'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s['a']
# Out:
# np.int64(10)

# %%
s['b']
# Out:
# np.int64(20)

# %%
data ={
    "Name": ["Omkar"],
    "Age": [19],
    "City": [ "Pune"]
}

# %%
data
# Out:
# {'Name': ['Omkar'], 'Age': [19], 'City': ['Pune']}

# %%
data = {
    "Roll_No":[100,200,300,500],
    "Name":['Omkar','Shrawan','Tanmay','Rahul'],
    "Marks":[99,100,101,626]
}

# %%
data
# Out:
# {'Roll_No': [100, 200, 300, 500],
#  'Name': ['Omkar', 'Shrawan', 'Tanmay', 'Rahul'],
#  'Marks': [99, 100, 101, 626]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Roll_No     Name  Marks
# 0      100    Omkar     99
# 1      200  Shrawan    100
# 2      300   Tanmay    101
# 3      500    Rahul    626

# %%
df.to_csv('Marks_data.csv',index = False)

# %%
df = pd.read_csv("Marks_data.csv")

# %%
df
# Out:
#    Roll_No     Name  Marks
# 0      100    Omkar     99
# 1      200  Shrawan    100
# 2      300   Tanmay    101
# 3      500    Rahul    626

# %%
df.head()
# Out:
#    Roll_No     Name  Marks
# 0      100    Omkar     99
# 1      200  Shrawan    100
# 2      300   Tanmay    101
# 3      500    Rahul    626

# %%
df.tail()
# Out:
#    Roll_No     Name  Marks
# 0      100    Omkar     99
# 1      200  Shrawan    100
# 2      300   Tanmay    101
# 3      500    Rahul    626

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Roll_No', 'Name', 'Marks'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll_No  4 non-null      int64
#  1   Name     4 non-null      object
#  2   Marks    4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#           Roll_No       Marks
# count    4.000000    4.000000
# mean   275.000000  231.500000
# std    170.782513  263.001267
# min    100.000000   99.000000
# 25%    175.000000   99.750000
# 50%    250.000000  100.500000
# 75%    350.000000  232.250000
# max    500.000000  626.000000

# %%
df.isnull().sum()
# Out:
# Roll_No    0
# Name       0
# Marks      0
# dtype: int64

# %%
df =df.drop_duplicates()

# %%
df
# Out:
#    Roll_No     Name  Marks
# 0      100    Omkar     99
# 1      200  Shrawan    100
# 2      300   Tanmay    101
# 3      500    Rahul    626

# %%
df['Marks'] = df['Marks'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll_No  4 non-null      int64
#  1   Name     4 non-null      object
#  2   Marks    4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df["Name"]
# Out:
# 0      Omkar
# 1    Shrawan
# 2     Tanmay
# 3      Rahul
# Name: Name, dtype: object

# %%
df[["Roll_No","Name"]]
# Out:
#    Roll_No     Name
# 0      100    Omkar
# 1      200  Shrawan
# 2      300   Tanmay
# 3      500    Rahul

# %%
df=df.sort_values(by="Marks",ascending=False)

# %%
df
# Out:
#    Roll_No     Name  Marks
# 3      500    Rahul    626
# 2      300   Tanmay    101
# 1      200  Shrawan    100
# 0      100    Omkar     99
