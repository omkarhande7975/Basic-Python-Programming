# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.DataFrame({
    "A":[50,60,70,80],
    "B":[40,55,65,75],
    "c":[30,45,55,65],
    "D":[20,35,45,55]
}, index=["Q1","Q2","Q3","Q4"])

# %%
df
# Out:
#      A   B   c   D
# Q1  50  40  30  20
# Q2  60  55  45  35
# Q3  70  65  55  45
# Q4  80  75  65  55

# %%
df.shape
# Out:
# (4, 4)

# %%
df.isnull()
# Out:
#         A      B      c      D
# Q1  False  False  False  False
# Q2  False  False  False  False
# Q3  False  False  False  False
# Q4  False  False  False  False

# %%
df.plot.line()
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.scatter(x="A",y="B")
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df["A"].plot.pie()
# Out:
# <Axes: ylabel='A'>

# %%
df = pd.DataFrame({
    "products":["pen","book","notebook"],
    "Sales":["100","120","300"],
    "Weeks":["sunday","Monday","sunday"]
}, index=["10","20","30"])

# %%
df
# Out:
#     products Sales   Weeks
# 10       pen   100  sunday
# 20      book   120  Monday
# 30  notebook   300  sunday
