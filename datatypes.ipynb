# %%
# integer

# %%
# integer means whole number

# %%
age = 20

# %%
print(age,type(age))
# Out:
# 20 <class 'int'>

# %%
#integer operation

# %%
a = 25
b = 10

# %%
#addtion

# %%
a + b
# Out:
# 35

# %%
#subtraction

# %%
a - b
# Out:
# 15

# %%
#Multiplication

# %%
a * b
# Out:
# 250

# %%
# division

# %%
a / b
# Out:
# 2.5

# %%
# Floor Division

# %%
a // b
# Out:
# 2

# %%
#Remainder

# %%
a % b
# Out:
# 5

# %%
 # Power

# %%
a ** b
# Out:
# 95367431640625

# %%
#string

# %%
#Sting means text

# %%
first_name = "omkar"
last_name = "hande"
course = "pyrthon programming"

# %%
print(type(first_name))
# Out:
# <class 'str'>

# %%
print(type(last_name))
# Out:
# <class 'str'>

# %%
print(type(course))
# Out:
# <class 'str'>

# %%
# string concatenation

# %%
first_name = "omkar"
last_name = "hande"

# %%
full_name = first_name + " " + last_name

# %%
full_name
# Out:
# 'omkar hande'

# %%
# srting repetition

# %%
word = "python "

# %%
print(word * 3)
# Out:
# python python python

# %%
word = "python"

# %%
print(word * 3)
# Out:
# pythonpythonpython

# %%
# srting indexing

# %%
language = "python"

# %%
language [0]
# Out:
# 'p'

# %%
language [1]
# Out:
# 'y'

# %%
language[-1]
# Out:
# 'n'

# %%
language[-2]
# Out:
# 'o'

# %%
#string slicing

# %%
language = "python programming"

# %%
language[0:6]
# Out:
# 'python'

# %%
language[7:18]
# Out:
# 'programming'

# %%
language[:6]
# Out:
# 'python'

# %%
language[7:]
# Out:
# 'programming'

# %%
language[6:18]
# Out:
# ' programming'

# %%
#string methods

# %%
message = "welcome to python programming"

# %%
message.upper()
# Out:
# 'WELCOME TO PYTHON PROGRAMMING'

# %%
message.lower()
# Out:
# 'welcome to python programming'

# %%
message.title()
# Out:
# 'Welcome To Python Programming'

# %%
message.capitalize()
# Out:
# 'Welcome to python programming'

# %%
len(message)
# Out:
# 29

# %%
# replace
# Used  to replace a word  or character in a string

# %%
text = "i like java"

# %%
new_text =text.replace("java","python")

# %%
print(new_text)
# Out:
# i like python

# %%
#split with separator
#used to split a sring into a list.

# %%
text = "omkar shrawan rushikesh"

# %%
words = text.split()

# %%
print(words)
# Out:
# ['omkar', 'shrawan', 'rushikesh']

# %%
#join
#used to join list items into a signal srting.

# %%
#strip

# %%
text = "  python  "

# %%
clean_text = text.strip()

# %%
clean_text
# Out:
# 'python'

# %%
#lstrip remove left spaces

# %%
text = "  HELLO"

# %%
text.lstrip()
# Out:
# 'HELLO'

# %%
#rstrip remove right spaces

# %%
text = "HELLO  "

# %%
text.rstrip()
# Out:
# 'HELLO'

# %%
#srting formating

# %%
name = "omkar"
age = "19"

# %%
print(f"my name is {name} and i am {age} years old.")
# Out:
# my name is omkar and i am 19 years old.

# %% [raw]
# subject = "java"

# %%
print(f"i am good in {subject}.")
# Out:
# i am good in java.

# %%
#mathematical operation inside f-string

# %%
a = 10
b = 5

# %%
print(f"Sum = {a + b}")
# Out:
# Sum = 15

# %%
# format

# %%
name = "omkar"
age = 22

# %%
print("My name is {} and i am {} years old.".format(name,age))
# Out:
# My name is omkar and i am 22 years old.

# %%
#boolean

# %%
is_student = True
is_employed = False

# %%
print(is_student, type(is_student))
# Out:
# True <class 'bool'>

# %%
print(is_employed, type(is_employed))
# Out:
# False <class 'bool'>

# %%
#logical operators

# %%
a = True
b = False

# %%
# AND

# %%
a and b
# Out:
# False

# %%
# OR

# %%
a or b
# Out:
# True

# %%
# Not

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
#Assignment Operator

# %%
x = 5

# %%
print(x)
# Out:
# 5

# %%
x = x + 5

# %%
print(x)
# Out:
# 13

# %%
# Membership operators

# %%
fruits = ["apple"," banana","mango"]

# %%
"apple" in fruits
# Out:
# True

# %%
"grapes" not in fruits
# Out:
# True

# %%
#identity operator

# %%
a = [1, 2, 3]
b = a
c = [1, 2, 3]

# %%
# True

# %%
a is b
# Out:
# True

# %%
# False

# %%
a is c
# Out:
# False

# %%
# True

# %%
a is not c
# Out:
# True

# %%
# Bitwise operators
