# %%
x = 10

# %%
x
# Out:
# 10

# %%
b = 10.80

# %%
b
# Out:
# 10.8

# %%
name = "omkar"

# %%
name
# Out:
# 'omkar'

# %%
name = "omkar shashikant hande"

# %%
name
# Out:
# 'omkar shashikant hande'

# %%
a = 10

# %%
b = 20

# %%
a + b
# Out:
# 30

# %%
print ("hello omkar hii")
# Out:
# hello omkar hii
